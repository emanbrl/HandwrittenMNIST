# %% [markdown]
# <a href="https://colab.research.google.com/github/emanbrl/HandwrittenMNIST/blob/main/mnist-classifier/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/emanbrl/HandwrittenMNIST.git
# Out:
# Cloning into 'HandwrittenMNIST'...
# ...

# %%
# %cd HandwrittenMNIST

# %% [markdown]
# # Project Introduction

# %% [markdown]
# # Import Libraries

# %% [markdown]
# # Load Dataset

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Build Neural Network

# %% [markdown]
# # Train Model

# %% [markdown]
# # Evaluate Model

# %% [markdown]
# # Experimentation

# %% [markdown]
# # Conclusion
